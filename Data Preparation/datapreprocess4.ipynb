# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
from bs4 import BeautifulSoup
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

headers = {
    "User-Agent": "Mozilla/5.0"
}

req = urllib.request.Request(link, headers=headers)
source = urllib.request.urlopen(req).read()
soup = BeautifulSoup(source, "lxml")

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12888\2803005693.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_html(str(tables[0]))[0]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12888\2803005693.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df2 = pd.read_html(str(tables[1]))[0]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12888\2803005693.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df3 = pd.read_html(str(tables[2]))[0]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12888\2803005693.py:4: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df
# Out:
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          3             The Grudge
# 1      J A N U A R Y         10             Underwater
# 2      J A N U A R Y         10            Like a Boss
# 3      J A N U A R Y         10          Three Christs
# 4      J A N U A R Y         10      Inherit the Viper
# ..               ...        ...                    ...
# 274  D E C E M B E R         25       We Can Be Heroes
# 275  D E C E M B E R         25      News of the World
# 276  D E C E M B E R         25  One Night in Miami...
# 277  D E C E M B E R         25  Promising Young Woman
# 278  D E C E M B E R         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1             20th Century Fox / Chernin Entertainment
# 2                   Paramount Pictures / Artists First
# 3                                            IFC Films
# 4    Lionsgate / Barry Films / Tycor International ...
# ..                                                 ...
# 274  Netflix / Troublemaker Studios / Double R Prod...
# 275  Universal Pictures / Playtone / Perfect World ...
# 276                                     Amazon Studios
# 277          Focus Features / FilmNation Entertainment
# 278                             Netflix / Bron Studios
#
#                                          Cast and crew   Ref.
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    [2]
# 1    William Eubank (director); Brian Duffield, Ada...    [3]
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    [4]
# 3    Jon Avnet (director/screenplay); Eric Nazarian...    NaN
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...    [5]
# ..                                                 ...    ...
# 274  Robert Rodriguez (director/screenplay); Priyan...  [247]
# 275  Paul Greengrass (director/screenplay); Luke Da...  [248]
# 276  Regina King (director); Kemp Powers (screenpla...  [249]
# 277  Emerald Fennell (director/screenplay); Carey M...  [250]
# 278  Kornél Mundruczó (director); Kata Wéber (scree...  [251]
#
# [279 rows x 6 columns]

# %%
df_2020 = df[['Title','Cast and crew']]
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 274       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 275      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 276  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 277  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 278      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [279 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '3089410d60cb236c58d58b49d9ca913b'

# %%
from tmdbv3api import Movie
import requests
import numpy as np

tmdb_movie = Movie()

def get_genre(x):
    try:
        result = tmdb_movie.search(x)
        if not result:
            return np.nan

        movie_id = result[0].id
        response = requests.get(
            f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb.api_key}",
            timeout=5
        )

        if response.status_code != 200:
            return np.nan

        data_json = response.json()

        if data_json.get("genres"):
            return " ".join(g["name"] for g in data_json["genres"])
        else:
            return np.nan

    except Exception:
        return np.nan

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12888\2588226551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 274       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 275      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 276  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 277  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 278      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                       genres
# 0                    Horror Mystery Thriller
# 1    Horror Science Fiction Action Adventure
# 2                                     Comedy
# 3                                      Drama
# 4                       Crime Thriller Drama
# ..                                       ...
# 274             Family Action Fantasy Comedy
# 275                  Drama Western Adventure
# 276                                    Drama
# 277                     Thriller Crime Drama
# 278                                    Drama
#
# [279 rows x 3 columns]

# %%
def get_director(x):
    if not isinstance(x, str):
        return np.nan

    if " (director)" in x:
        return x.split(" (director)")[0]

    if " (directors)" in x:
        return x.split(" (directors)")[0]

    if " (director/screenplay)" in x:
        return x.split(" (director/screenplay)")[0]

    return np.nan

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12888\3848435694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12888\1815024756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    # nếu x là NaN hoặc không phải string
    if pd.isna(x) or not isinstance(x, str):
        return np.nan

    # tách phần sau screenplay);
    cast_part = x.split("screenplay); ")[-1]
    casts = cast_part.split(", ")

    if len(casts) < 2:
        return np.nan
    else:
        return casts[1]

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if pd.isna(x) or not isinstance(x, str):
        return np.nan

    cast_part = x.split("screenplay); ")[-1]
    casts = cast_part.split(", ")

    if len(casts) < 3:
        return np.nan
    else:
        return casts[2]

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 274       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 275      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 276  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 277  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 278      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                       genres     director_name  \
# 0                    Horror Mystery Thriller     Nicolas Pesce
# 1    Horror Science Fiction Action Adventure    William Eubank
# 2                                     Comedy     Miguel Arteta
# 3                                      Drama         Jon Avnet
# 4                       Crime Thriller Drama    Anthony Jerjen
# ..                                       ...               ...
# 274             Family Action Fantasy Comedy  Robert Rodriguez
# 275                  Drama Western Adventure   Paul Greengrass
# 276                                    Drama       Regina King
# 277                     Thriller Crime Drama   Emerald Fennell
# 278                                    Drama  Kornél Mundruczó
#
#               actor_1_name       actor_2_name     actor_3_name
# 0       Andrea Riseborough      Demián Bichir         John Cho
# 1          Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2          Tiffany Haddish         Rose Byrne      Salma Hayek
# 3             Richard Gere     Peter Dinklage   Walton Goggins
# 4            Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                     ...                ...              ...
# 274  Priyanka Chopra Jonas       Pedro Pascal    YaYa Gosselin
# 275              Tom Hanks      Helena Zengel              NaN
# 276      Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 277         Carey Mulligan         Bo Burnham      Alison Brie
# 278          Vanessa Kirby       Shia LaBeouf     Molly Parker
#
# [279 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 274  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 275   Paul Greengrass              Tom Hanks      Helena Zengel
# 276       Regina King      Kingsley Ben-Adir          Eli Goree
# 277   Emerald Fennell         Carey Mulligan         Bo Burnham
# 278  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                   genres  \
# 0           John Cho                  Horror Mystery Thriller
# 1    Jessica Henwick  Horror Science Fiction Action Adventure
# 2        Salma Hayek                                   Comedy
# 3     Walton Goggins                                    Drama
# 4     Chandler Riggs                     Crime Thriller Drama
# ..               ...                                      ...
# 274    YaYa Gosselin             Family Action Fantasy Comedy
# 275              NaN                  Drama Western Adventure
# 276      Aldis Hodge                                    Drama
# 277      Alison Brie                     Thriller Crime Drama
# 278     Molly Parker                                    Drama
#
#                movie_title
# 0               The Grudge
# 1               Underwater
# 2              Like a Boss
# 3            Three Christs
# 4        Inherit the Viper
# ..                     ...
# 274       We Can Be Heroes
# 275      News of the World
# 276  One Night in Miami...
# 277  Promising Young Woman
# 278      Pieces of a Woman
#
# [279 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     4
# actor_1_name      0
# actor_2_name      5
# actor_3_name     29
# genres            3
# movie_title       0
# comb             34
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12888\2267385682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 273       Pete Docter             Jamie Foxx           Tina Fey
# 274  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 276       Regina King      Kingsley Ben-Adir          Eli Goree
# 277   Emerald Fennell         Carey Mulligan         Bo Burnham
# 278  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                       genres  \
# 0           John Cho                      Horror Mystery Thriller
# 1    Jessica Henwick      Horror Science Fiction Action Adventure
# 2        Salma Hayek                                       Comedy
# 3     Walton Goggins                                        Drama
# 4     Chandler Riggs                         Crime Thriller Drama
# ..               ...                                          ...
# 273    Graham Norton  Animation Family Comedy Fantasy Drama Music
# 274    YaYa Gosselin                 Family Action Fantasy Comedy
# 276      Aldis Hodge                                        Drama
# 277      Alison Brie                         Thriller Crime Drama
# 278     Molly Parker                                        Drama
#
#                movie_title                                               comb
# 0               the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1               underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2              like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3            three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4        inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                     ...                                                ...
# 273                   soul  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 274       we can be heroes  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 276  one night in miami...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 277  promising young woman  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 278      pieces of a woman  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [245 rows x 7 columns]

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5858  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5859            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5860              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5861   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5862         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5858         Rashida Jones  Animation Action Adventure Comedy Family
# 5859         Florence Pugh                     Drama Romance History
# 5860           Mark Strong                  War History Drama Action
# 5861           Brie Larson                       Drama Crime History
# 5862           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5858                                  spies in disguise
# 5859                                       little women
# 5860                                               1917
# 5861                                         just mercy
# 5862                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5858  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5859  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5860  George MacKay Dean-Charles Chapman Mark Strong...
# 5861  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5862  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5863 rows x 7 columns]

# %%
final_df = pd.concat([old_df, new_df20], ignore_index=True)
final_df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 6103        Pete Docter             Jamie Foxx          Tina Fey
# 6104   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 6105        Regina King      Kingsley Ben-Adir         Eli Goree
# 6106    Emerald Fennell         Carey Mulligan        Bo Burnham
# 6107   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                                       genres  \
# 0                Wes Studi              Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                     Action Adventure Fantasy
# 2         Stephanie Sigman                    Action Adventure Thriller
# 3     Joseph Gordon-Levitt                              Action Thriller
# 4                  unknown                                  Documentary
# ...                    ...                                          ...
# 6103         Graham Norton  Animation Family Comedy Fantasy Drama Music
# 6104         YaYa Gosselin                 Family Action Fantasy Comedy
# 6105           Aldis Hodge                                        Drama
# 6106           Alison Brie                         Thriller Crime Drama
# 6107          Molly Parker                                        Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6103                                               soul
# 6104                                   we can be heroes
# 6105                              one night in miami...
# 6106                              promising young woman
# 6107                                  pieces of a woman
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6103  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 6104  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 6105  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6106  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 6107  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [6108 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
