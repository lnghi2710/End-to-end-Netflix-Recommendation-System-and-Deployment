# %%
import pandas as pd
import numpy as np
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"

headers = {
    "User-Agent": "Mozilla/5.0"
}

html = requests.get(url, headers=headers).text

tables = pd.read_html(html, header=0)

df1 = tables[2]
df2 = tables[3]
df3 = tables[4]
df4 = tables[5]
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15848\987551537.py:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html, header=0)

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 246  D E C E M B E R         21               Second Act
# 247  D E C E M B E R         25          Holmes & Watson
# 248  D E C E M B E R         25                     Vice
# 249  D E C E M B E R         25      On the Basis of Sex
# 250  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 246                                  STX Entertainment
# 247  Columbia Pictures / Gary Sanchez Productions /...
# 248          Annapurna Pictures / Plan B Entertainment
# 249                                     Focus Features
# 250                                 Annapurna Pictures
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Christopher Radcliff (director/screenplay); La...    [3]
# 2    Jaume Collet-Serra (director); Byron Willinger...    [4]
# 3    Babak Najafi (director); John S. Newman, Chris...    [5]
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...    [6]
# ..                                                 ...    ...
# 246  Peter Segal (director); Justin Zackham, Elaine...  [238]
# 247  Etan Cohen (director/screenplay); Will Ferrell...  [142]
# 248  Adam McKay (director/screenplay); Christian Ba...  [117]
# 249  Mimi Leder (director); Daniel Stiepleman (scre...  [207]
# 250  Karyn Kusama (director); Phil Hay, Matt Manfre...  [239]
#
# [251 rows x 6 columns]

# %%
#get API Key here: https://www.themoviedb.org/settings/api
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '3089410d60cb236c58d58b49d9ca913b'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()

def get_genre(title):
    if not title or title == 'nan':
        return np.nan

    try:
        result = tmdb_movie.search(title)

        if not result:
            return np.nan

        movie_id = result[0].id

        response = requests.get(
            f"https://api.themoviedb.org/3/movie/{movie_id}",
            params={"api_key": tmdb.api_key},
            timeout=10
        )

        data_json = response.json()

        genres = data_json.get("genres", [])

        if not genres:
            return np.nan

        return " ".join(g["name"] for g in genres)

    except Exception:
        return np.nan

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 246  D E C E M B E R         21               Second Act
# 247  D E C E M B E R         25          Holmes & Watson
# 248  D E C E M B E R         25                     Vice
# 249  D E C E M B E R         25      On the Basis of Sex
# 250  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 246                                  STX Entertainment
# 247  Columbia Pictures / Gary Sanchez Productions /...
# 248          Annapurna Pictures / Plan B Entertainment
# 249                                     Focus Features
# 250                                 Annapurna Pictures
#
#                                          Cast and crew   Ref.  \
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Christopher Radcliff (director/screenplay); La...    [3]
# 2    Jaume Collet-Serra (director); Byron Willinger...    [4]
# 3    Babak Najafi (director); John S. Newman, Chris...    [5]
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...    [6]
# ..                                                 ...    ...
# 246  Peter Segal (director); Justin Zackham, Elaine...  [238]
# 247  Etan Cohen (director/screenplay); Will Ferrell...  [142]
# 248  Adam McKay (director/screenplay); Christian Ba...  [117]
# 249  Mimi Leder (director); Daniel Stiepleman (scre...  [207]
# 250  Karyn Kusama (director); Phil Hay, Matt Manfre...  [239]
#
#                       genres
# 0            Horror Thriller
# 1              Drama Mystery
# 2    Action Thriller Mystery
# 3      Thriller Action Crime
# 4      Action Crime Thriller
# ..                       ...
# 246           Romance Comedy
# 247     Comedy Mystery Crime
# 248             Drama Comedy
# 249            Drama History
# 250      Adventure Drama War
#
# [251 rows x 7 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 246               Second Act
# 247          Holmes & Watson
# 248                     Vice
# 249      On the Basis of Sex
# 250                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 246  Peter Segal (director); Justin Zackham, Elaine...
# 247  Etan Cohen (director/screenplay); Will Ferrell...
# 248  Adam McKay (director/screenplay); Christian Ba...
# 249  Mimi Leder (director); Daniel Stiepleman (scre...
# 250  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                       genres
# 0            Horror Thriller
# 1              Drama Mystery
# 2    Action Thriller Mystery
# 3      Thriller Action Crime
# 4      Action Crime Thriller
# ..                       ...
# 246           Romance Comedy
# 247     Comedy Mystery Crime
# 248             Drama Comedy
# 249            Drama History
# 250      Adventure Drama War
#
# [251 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x: #we are getting "director"
        return x.split(" (director)")[0]
    elif " (directors)" in x: #we are getting "directors" with "s"
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0] #we are getting "directors/screenplay"

# %%
#let's apply the above function on the "Cast and crew" column
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15848\2371950425.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15848\3828479394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if pd.isna(x):
        return np.nan

    # nếu dữ liệu là string dạng list dict
    if isinstance(x, str):
        try:
            x = ast.literal_eval(x)
        except:
            return np.nan

    if not isinstance(x, list) or len(x) <= 1:
        return np.nan

    return x[1].get('name', np.nan)

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15848\2881346986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if pd.isna(x):
        return np.nan

    if not isinstance(x, str):
        return np.nan

    parts = x.split("screenplay); ")
    if len(parts) < 2:
        return np.nan

    actors = parts[-1].split(", ")
    if len(actors) < 3:
        return np.nan

    return actors[2]

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 246                                        Peter Segal
# 247                                         Etan Cohen
# 248                                         Adam McKay
# 249                                         Mimi Leder
# 250                                       Karyn Kusama
#
#                                    actor_1_name  actor_2_name  \
# 0                                     Lin Shaye           NaN
# 1    Lauren Wolkstein (director); Alex Pettyfer           NaN
# 2                                   Liam Neeson           NaN
# 3                              Taraji P. Henson           NaN
# 4                                  Bruce Willis           NaN
# ..                                          ...           ...
# 246                              Jennifer Lopez           NaN
# 247                                Will Ferrell           NaN
# 248                              Christian Bale           NaN
# 249                              Felicity Jones           NaN
# 250                               Nicole Kidman           NaN
#
#         actor_3_name                   genres              movie_title
# 0     Leigh Whannell          Horror Thriller  Insidious: The Last Key
# 1      Emily Althaus            Drama Mystery         The Strange Ones
# 2     Patrick Wilson  Action Thriller Mystery             The Commuter
# 3        Billy Brown    Thriller Action Crime               Proud Mary
# 4      Shawn Ashmore    Action Crime Thriller         Acts of Violence
# ..               ...                      ...                      ...
# 246  Vanessa Hudgens           Romance Comedy               Second Act
# 247     Rebecca Hall     Comedy Mystery Crime          Holmes & Watson
# 248     Steve Carell             Drama Comedy                     Vice
# 249   Justin Theroux            Drama History      On the Basis of Sex
# 250     Toby Kebbell      Adventure Drama War                Destroyer
#
# [251 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 246                                        Peter Segal
# 247                                         Etan Cohen
# 248                                         Adam McKay
# 249                                         Mimi Leder
# 250                                       Karyn Kusama
#
#                                    actor_1_name actor_2_name     actor_3_name  \
# 0                                     Lin Shaye      unknown   Leigh Whannell
# 1    Lauren Wolkstein (director); Alex Pettyfer      unknown    Emily Althaus
# 2                                   Liam Neeson      unknown   Patrick Wilson
# 3                              Taraji P. Henson      unknown      Billy Brown
# 4                                  Bruce Willis      unknown    Shawn Ashmore
# ..                                          ...          ...              ...
# 246                              Jennifer Lopez      unknown  Vanessa Hudgens
# 247                                Will Ferrell      unknown     Rebecca Hall
# 248                              Christian Bale      unknown     Steve Carell
# 249                              Felicity Jones      unknown   Justin Theroux
# 250                               Nicole Kidman      unknown     Toby Kebbell
#
#                       genres              movie_title  \
# 0            Horror Thriller  insidious: the last key
# 1              Drama Mystery         the strange ones
# 2    Action Thriller Mystery             the commuter
# 3      Thriller Action Crime               proud mary
# 4      Action Crime Thriller         acts of violence
# ..                       ...                      ...
# 246           Romance Comedy               second act
# 247     Comedy Mystery Crime          holmes & watson
# 248             Drama Comedy                     vice
# 249            Drama History      on the basis of sex
# 250      Adventure Drama War                destroyer
#
#                                                   comb
# 0    Lin Shaye unknown Leigh Whannell Adam Robitel ...
# 1    Lauren Wolkstein (director); Alex Pettyfer unk...
# 2    Liam Neeson unknown Patrick Wilson Jaume Colle...
# 3    Taraji P. Henson unknown Billy Brown Babak Naj...
# 4    Bruce Willis unknown Shawn Ashmore Brett Donow...
# ..                                                 ...
# 246  Jennifer Lopez unknown Vanessa Hudgens Peter S...
# 247  Will Ferrell unknown Rebecca Hall Etan Cohen C...
# 248  Christian Bale unknown Steve Carell Adam McKay...
# 249  Felicity Jones unknown Justin Theroux Mimi Led...
# 250  Nicole Kidman unknown Toby Kebbell Karyn Kusam...
#
# [251 rows x 7 columns]

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"

headers = {
    "User-Agent": "Mozilla/5.0"
}

html = requests.get(link, headers=headers).text

tables = pd.read_html(html, header=0)

df1 = tables[2]
df2 = tables[3]
df3 = tables[4]
df4 = tables[5]
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15848\3197132418.py:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html, header=0)

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df
# Out:
#              Opening  Opening.1              Title  \
# 0      J A N U A R Y          4        Escape Room
# 1      J A N U A R Y          4         Rust Creek
# 2      J A N U A R Y          4   American Hangman
# 3      J A N U A R Y         11   A Dog's Way Home
# 4      J A N U A R Y         11         The Upside
# ..               ...        ...                ...
# 246  D E C E M B E R         25  Spies in Disguise
# 247  D E C E M B E R         25       Little Women
# 248  D E C E M B E R         25               1917
# 249  D E C E M B E R         25         Just Mercy
# 250  D E C E M B E R         27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 246  20th Century Fox Animation / Blue Sky Studios ...
# 247            Columbia Pictures / Regency Enterprises
# 248           Universal Pictures / DreamWorks Pictures
# 249                Warner Bros. Pictures / Participant
# 250                                               Neon
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 246  Nick Bruno, Troy Quane (directors); Brad Copel...  [133]
# 247  Greta Gerwig (director/screenplay); Saoirse Ro...  [227]
# 248  Sam Mendes (director/screenplay); Krysty Wilso...  [228]
# 249  Destin Daniel Cretton (director/screenplay), A...  [229]
# 250  Chinonye Chukwu (director/screenplay); Alfre W...  [230]
#
# [251 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 246  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 247       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 248               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 249         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 250           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# 0                     Horror Thriller Mystery
# 1                 Thriller Drama Action Crime
# 2                                    Thriller
# 3                      Drama Adventure Family
# 4                                Comedy Drama
# ..                                        ...
# 246  Animation Action Adventure Comedy Family
# 247                     Drama Romance History
# 248                  War History Drama Action
# 249                       Drama Crime History
# 250                                     Drama
#
# [251 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15848\2427931457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15848\21458062.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if pd.isna(x):
        return np.nan

    if not isinstance(x, str):
        return np.nan

    parts = x.split("screenplay); ")
    if len(parts) < 2:
        return np.nan

    actors = parts[-1].split(", ")
    if len(actors) < 2:
        return np.nan

    return actors[1]

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15848\56863382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if not isinstance(x, str):
        return np.nan

    actors = x.split("screenplay); ")[-1].split(", ")

    if len(actors) < 3:
        return np.nan
    else:
        return actors[2]

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 246  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 247            Greta Gerwig        Saoirse Ronan           Emma Watson
# 248              Sam Mendes        George MacKay  Dean-Charles Chapman
# 249   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 250         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# 0    Deborah Ann Woll                   Horror Thriller Mystery
# 1        Sean O'Bryan               Thriller Drama Action Crime
# 2       Oliver Dennis                                  Thriller
# 3     Alexandra Shipp                    Drama Adventure Family
# 4       Nicole Kidman                              Comedy Drama
# ..                ...                                       ...
# 246     Rashida Jones  Animation Action Adventure Comedy Family
# 247     Florence Pugh                     Drama Romance History
# 248       Mark Strong                  War History Drama Action
# 249       Brie Larson                       Drama Crime History
# 250       Aldis Hodge                                     Drama
#
#            movie_title                                               comb
# 0          escape room  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1           rust creek  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2     american hangman  Donald Sutherland Vincent Kartheiser Oliver De...
# 3     a dog's way home  Bryce Dallas Howard Edward James Olmos Alexand...
# 4           the upside  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                 ...                                                ...
# 246  spies in disguise  Will Smith Tom Holland Rashida Jones Nick Brun...
# 247       little women  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 248               1917  George MacKay Dean-Charles Chapman Mark Strong...
# 249         just mercy  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 250           clemency  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [251 rows x 7 columns]

# %%
my_df = pd.concat([new_df18, new_df19], ignore_index=True)
my_df
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 497                             Nick Bruno, Troy Quane
# 498                                       Greta Gerwig
# 499                                         Sam Mendes
# 500                              Destin Daniel Cretton
# 501                                    Chinonye Chukwu
#
#                                    actor_1_name          actor_2_name  \
# 0                                     Lin Shaye               unknown
# 1    Lauren Wolkstein (director); Alex Pettyfer               unknown
# 2                                   Liam Neeson               unknown
# 3                              Taraji P. Henson               unknown
# 4                                  Bruce Willis               unknown
# ..                                          ...                   ...
# 497                                  Will Smith           Tom Holland
# 498                               Saoirse Ronan           Emma Watson
# 499                               George MacKay  Dean-Charles Chapman
# 500                           Michael B. Jordan            Jamie Foxx
# 501                               Alfre Woodard        Wendell Pierce
#
#        actor_3_name                                    genres  \
# 0    Leigh Whannell                           Horror Thriller
# 1     Emily Althaus                             Drama Mystery
# 2    Patrick Wilson                   Action Thriller Mystery
# 3       Billy Brown                     Thriller Action Crime
# 4     Shawn Ashmore                     Action Crime Thriller
# ..              ...                                       ...
# 497   Rashida Jones  Animation Action Adventure Comedy Family
# 498   Florence Pugh                     Drama Romance History
# 499     Mark Strong                  War History Drama Action
# 500     Brie Larson                       Drama Crime History
# 501     Aldis Hodge                                     Drama
#
#                  movie_title  \
# 0    insidious: the last key
# 1           the strange ones
# 2               the commuter
# 3                 proud mary
# 4           acts of violence
# ..                       ...
# 497        spies in disguise
# 498             little women
# 499                     1917
# 500               just mercy
# 501                 clemency
#
#                                                   comb
# 0    Lin Shaye unknown Leigh Whannell Adam Robitel ...
# 1    Lauren Wolkstein (director); Alex Pettyfer unk...
# 2    Liam Neeson unknown Patrick Wilson Jaume Colle...
# 3    Taraji P. Henson unknown Billy Brown Babak Naj...
# 4    Bruce Willis unknown Shawn Ashmore Brett Donow...
# ..                                                 ...
# 497  Will Smith Tom Holland Rashida Jones Nick Brun...
# 498  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 499  George MacKay Dean-Charles Chapman Mark Strong...
# 500  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 501  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [502 rows x 7 columns]

# %%
old_df = pd.read_csv('new_data.csv')
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5359       Keith Stanfield                   Romance Comedy
# 5360     Jean Louisa Kelly                          Romance
# 5361        Tiitus Rantala                   Romance Comedy
# 5362           Gina Holden       Crime Comedy Action Family
# 5363        Akshaye Khanna             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5359                       the incredible jessica james
# 5360                                  can't buy my love
# 5361                   thick lashes of lauri mäntyvaara
# 5362                        cop and a half: new recruit
# 5363                                                mom
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5359  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 7 columns]

# %%
final_df = pd.concat([old_df, my_df], ignore_index=True)
final_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5861  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5862            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5863              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5864   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5865         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5861         Rashida Jones  Animation Action Adventure Comedy Family
# 5862         Florence Pugh                     Drama Romance History
# 5863           Mark Strong                  War History Drama Action
# 5864           Brie Larson                       Drama Crime History
# 5865           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5861                                  spies in disguise
# 5862                                       little women
# 5863                                               1917
# 5864                                         just mercy
# 5865                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5861  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5862  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5863  George MacKay Dean-Charles Chapman Mark Strong...
# 5864  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5865  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5866 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           3
# movie_title      0
# comb             3
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('final_data.csv',index=False)
